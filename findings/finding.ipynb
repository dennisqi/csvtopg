# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv = '../data/loan_cleaned_all_tb.csv'

# %%
df = pd.read_csv(csv)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Number of missing grade
df.grade.isnull().sum()
# Out:
# 0

# %%
# Show number of records for each grade
grade_counts = df.grade.value_counts().sort_index()
sns.barplot(x=grade_counts.index, y=grade_counts.values)
plt.title('Number of records for each grade')
plt.xlabel('Grade')
plt.ylabel('Number of records')
# Out:
# Text(0,0.5,'Number of records')

# %%
# Number of records changed over time
df.issue_d = pd.to_datetime(df.issue_d)
plt.figure(figsize=(10, 8))
df.issue_d.value_counts().plot()
plt.title('Number of records for each month')
plt.xlabel('Month')
plt.ylabel('Number of records')
# Out:
# Text(0,0.5,'Number of records')

# %%
# Number of records changes over time for each grade
plt.figure(figsize=(15, 11))
grades = sorted(df.grade.unique())
for letter_grade in grades:
    records = df.loc[df['grade'] == letter_grade]
    records.issue_d.value_counts().plot()
plt.legend(grades)
plt.title('Number of records for each month for each grade')
plt.xlabel('Month')
plt.ylabel('Number of records')
# Out:
# Text(0,0.5,'Number of records')

# %%
# Average loan amount changes over time for each grade
plt.figure(figsize=(15, 11))
grades = sorted(df.grade.unique())
for letter_grade in grades:
    records = df.loc[df['grade'] == letter_grade]
    records.groupby(['issue_d']).loan_amnt.mean().plot()
plt.legend(grades)
plt.title('Average loan amount for each month')
plt.xlabel('Month')
plt.ylabel('Number of records')
# Out:
# Text(0,0.5,'Number of records')

# %%
# Average loan amount changes over time for each grade
plt.figure(figsize=(15, 11))
grades = ['A', 'B', 'C', 'D', 'E']
for letter_grade in grades:
    records = df.loc[df['grade'] == letter_grade]
    records.groupby(['issue_d']).loan_amnt.mean().plot()
plt.legend(grades)
plt.title('Average loan amount for each month')
plt.xlabel('Month')
plt.ylabel('Number of records')
# Out:
# Text(0,0.5,'Number of records')

# %%
for letter_grade in grades:
    records = df.loc[df['grade'] == letter_grade]
    print(letter_grade)
    print(records.loan_amnt.describe())
# Out:
# A
# count    148185.000000
# mean      14039.767014
# std        7501.997247
# min         500.000000
# 25%        8000.000000
# 50%       12000.000000
# 75%       20000.000000
# max       35000.000000
# Name: loan_amnt, dtype: float64
# B
# count    254510.000000
# mean      13643.668029
# std        7760.977990
# min         500.000000
# 25%        8000.000000
# 50%       12000.000000
# 75%       18000.000000
# max       35000.000000
# Name: loan_amnt, dtype: float64
# C
# count    245843.000000
# mean      14466.485521
# std        8538.756337
# min         500.000000
# 25%        8000.000000
# 50%       12000.000000
# 75%       20000.000000
# max       35000.000000
# Name: loan_amnt, dtype: float64
# D
# count    139531.000000
# mean      15459.415112
# std        9012.650221
# min         500.000000
# 25%        8500.000000
# 50%       14000.000000
# 75%       21000.000000
# max       35000.000000
# Name: loan_amnt, dtype: float64
# E
# count    70703.000000
# ...
